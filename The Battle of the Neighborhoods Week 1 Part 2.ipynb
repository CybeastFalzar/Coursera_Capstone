# %% [markdown]
# # Introduction

# %% [markdown]
# ### Background:
# New York has such a rich and diverse culture being a mix of many different types of people from every color, creed, and ethnicity. This is one of the reasons New York City is one of the most romanticised and popular cities in the US. As the song goes, "New York, city were dreams are made of, there's nothing you can't do now that your in New York." However, when most tourists go to New York they glance over one of its signature dishes being the, bacon egg and cheese which captivates the stuggle and success in New York. This is similar to Philadelphia and its philly cheese steak. This is something that is deep rooted in the culture of the city and is a staple at close to all deli's. However, another city that has the same status as New York would be Los Angeles where the bacon egg and cheese scene is big over there. Because of the high status of these countries tourists would love to know where to best spend their time.
#
# ### Problem:
# The problem presented here is which of these two cities has more options for tourists to endulge in this sandwitch? And which of these cities would this be more convenient?

# %% [markdown]
# # Data Selection

# %% [markdown]
# ### Data Sources:
# The FourSquare API will be used to collect data about deli's in New York City. What will happen after is that I will narrow this down to the top 5 delis in New York City that will be suitable for the new tourists. Because deli's are such a huge part of the culture of NYC, you will be able to connect and meet so many more new people and interact with many different ethnical backgrounds. FourSqaure's API is perfect for a project like this were I am able to get the geodata and map out my results based on the data that I am using such the ratings of the delis. While I have used the FourSquare database, the libraries I have used included, Numpy, Pandas, requests, and folium. Folium is a library that allows the maps to be rendered.

# %% [markdown]
# Actually getting the dataset from FourSquare was incredibly easy as what you need is your developer account Client ID and Secret ID as well as the version of the API with the category ID from the dataset that you'd want. For this I used a dataset which included all deli's and then was able to sort out only the information for New York and Los Angeles. The specific information that I collected was the name of the venue, address, latitude and longitude. These columns were named Name, Adress, Lat and Lng respectively. Another important piece of information taken was the amount of such deli's in both of the cities to what we would know which of the cities has a wider range of deli's for tourists to explore and try.

# %% [markdown]
# Using the Four Square API through the venues channel, I used a query to find different deli's in the
# cities as well as included a category identifier to only search for deli's. The Category ID for deli's
# was: 4bf58dd8d48988d146941735.
# An example of a request would be
# 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&near={}&limit={}&
# categoryId={}'.format( CLIENT_ID, CLIENT_SECRET, VERSION, city, LIMIT,
# "4bf58dd8d48988d146941735")
#
# What is happening here is that rather than writing criteria such as the client ID in the request a
# variable can be used here for the criteria so it is more easily understood. Two requests were made,
# one for New York and the other for Los Angeles and what was mapped was the top 100 deli's as the
# limit of 100 is given to us by Four Square.
#
# What we see here is that New York has more deli's than Los Angeles which gives the tourists a
# much better variety. To determine which city would be more convenient I calculated a center
# coordinate of the venues to get the mean longitude and latitude values. Then I calculated the mean
# of the Euclidean distance from each venue to the mean coordinates. That was my indicator, mean
# distance to the mean coordinate.

# %% [markdown]
# ![FinalWeek4Part1.JPG](attachment:FinalWeek4Part1.JPG)

# %% [markdown]
# ![FinalWeek4Part2.JPG](attachment:FinalWeek4Part2.JPG)
